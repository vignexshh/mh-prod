# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/namanmuktha/Desktop/crewlabs/mh-prod/Tel & Ap Data/telangana_management1.csv')

# %%
df.head()
# Out:
#                                              COLLEGE   RANK LOC  CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  31229  OU   OC  M   NaN
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL   OC  F   NaN
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  37371  NL  BCE  F   MSM
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41646  NL   OC  F   NaN
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41962  NL   OC  M   NaN
#
#    NRI ACDS  EWS PHASE
# 0  NaN  NaN  NaN    P1
# 1  NaN  NaN  NaN    P1
# 2  NaN  NaN  NaN    P1
# 3  NaN  NaN  NaN    P1
# 4  NaN  NaN  NaN    P1

# %%
df1=pd.read_csv('/Users/namanmuktha/Desktop/crewlabs/mh-prod/Tel & Ap Data/telangana_management2.csv')

# %%
df1.head()
# Out:
#                                              COLLEGE   RANK LOC CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL  OC  F   NaN
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  34091  NL  OC  M   NaN
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41646  NL  OC  F   NaN
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  44584  NL  OC  M   NaN
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  45505  NL  OC  M   NaN
#
#    NRI ACDS  EWS PHASE
# 0  NaN  NaN  NaN    P1
# 1  NaN  NaN  NaN    P2
# 2  NaN  NaN  NaN    P1
# 3  NaN  NaN  NaN    P1
# 4  NaN  NaN  NaN    P1

# %%
df2=pd.read_csv('/Users/namanmuktha/Desktop/crewlabs/mh-prod/Tel & Ap Data/telangana_management3.csv')
df2.head()
# Out:
#                                              COLLEGE   RANK LOC CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL  OC  F   NaN
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  34091  NL  OC  M   NaN
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41646  NL  OC  F   NaN
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  44584  NL  OC  M   NaN
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  45505  NL  OC  M   NaN
#
#    NRI ACDS  EWS PHASE
# 0  NaN  NaN  NaN    P1
# 1  NaN  NaN  NaN    P2
# 2  NaN  NaN  NaN    P1
# 3  NaN  NaN  NaN    P1
# 4  NaN  NaN  NaN    P1

# %%
df3=pd.read_csv('/Users/namanmuktha/Desktop/crewlabs/mh-prod/Tel & Ap Data/telangana_management4.csv')
df3.head()
# Out:
#                                              COLLEGE   RANK LOC CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL  OC  F   NaN
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  34091  NL  OC  M   NaN
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41646  NL  OC  F   NaN
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  44584  NL  OC  M   NaN
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  45505  NL  OC  M   NaN
#
#    NRI ACDS  EWS PHASE
# 0  NaN  NaN  NaN    P1
# 1  NaN  NaN  NaN    P2
# 2  NaN  NaN  NaN    P1
# 3  NaN  NaN  NaN    P1
# 4  NaN  NaN  NaN    P1

# %%
df4=pd.read_csv('/Users/namanmuktha/Desktop/crewlabs/mh-prod/Tel & Ap Data/telangana_management5.csv')
df4.head()
# Out:
#                                              COLLEGE   RANK LOC  CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL   OC  F   NaN
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  34091  NL   OC  M   NaN
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  63027  OU   OC  M   NaN
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  65907  OU   OC  F   NaN
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  79356  OU  BCD  M   NaN
#
#    NRI ACDS  EWS PHASE
# 0  NaN  NaN  NaN    P1
# 1  NaN  NaN  NaN    P2
# 2  NaN  NaN  NaN    P1
# 3  NaN  NaN  NaN    P1
# 4  NaN  NaN  NaN    P1

# %%
df.shape
# Out:
# (2416, 10)

# %%
df1.shape
# Out:
# (2094, 10)

# %%
df2.shape
# Out:
# (2194, 10)

# %%
df3.shape
# Out:
# (2323, 10)

# %%
df4.shape
# Out:
# (2323, 10)

# %%
df_total=pd.concat([df,df1,df2,df3,df4],join='inner')

# %%
df_total.head()
# Out:
#                                              COLLEGE   RANK LOC  CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  31229  OU   OC  M   NaN
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL   OC  F   NaN
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  37371  NL  BCE  F   MSM
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41646  NL   OC  F   NaN
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41962  NL   OC  M   NaN
#
#    NRI ACDS  EWS PHASE
# 0  NaN  NaN  NaN    P1
# 1  NaN  NaN  NaN    P1
# 2  NaN  NaN  NaN    P1
# 3  NaN  NaN  NaN    P1
# 4  NaN  NaN  NaN    P1

# %%
df_total.shape
# Out:
# (11350, 10)

# %%
df_total['MINOR']=df_total['MINOR'].fillna(value='NO')
df_total['NRI']=df_total['NRI'].fillna(value='NO')
df_total['ACDS']=df_total['ACDS'].fillna(value='NO')

# %%
df_total.head()
# Out:
#                                              COLLEGE   RANK LOC  CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  31229  OU   OC  M    NO
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL   OC  F    NO
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  37371  NL  BCE  F   MSM
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41646  NL   OC  F    NO
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41962  NL   OC  M    NO
#
#   NRI ACDS  EWS PHASE
# 0  NO   NO  NaN    P1
# 1  NO   NO  NaN    P1
# 2  NO   NO  NaN    P1
# 3  NO   NO  NaN    P1
# 4  NO   NO  NaN    P1

# %%
df_total['EWS'].unique()
# Out:
# array([nan])

# %%
df_total.isna().sum()
# Out:
# COLLEGE        0
# RANK           0
# LOC           51
# CAT           17
# SX            17
# MINOR          0
# NRI            0
# ACDS           0
# EWS        11350
# PHASE         17
# dtype: int64

# %%
df_total=df_total.drop(['EWS'],axis=1)

# %%
df_total.isna().sum()
# Out:
# COLLEGE     0
# RANK        0
# LOC        51
# CAT        17
# SX         17
# MINOR       0
# NRI         0
# ACDS        0
# PHASE      17
# dtype: int64

# %%
df_total=df_total.dropna()

# %%
df_total.isna().sum()
# Out:
# COLLEGE    0
# RANK       0
# LOC        0
# CAT        0
# SX         0
# MINOR      0
# NRI        0
# ACDS       0
# PHASE      0
# dtype: int64

# %%
df_total.head()
# Out:
#                                              COLLEGE   RANK LOC  CAT SX MINOR  \
# 0  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  31229  OU   OC  M    NO
# 1  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  32375  NL   OC  F    NO
# 2  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  37371  NL  BCE  F   MSM
# 3  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41646  NL   OC  F    NO
# 4  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...  41962  NL   OC  M    NO
#
#   NRI ACDS PHASE
# 0  NO   NO    P1
# 1  NO   NO    P1
# 2  NO   NO    P1
# 3  NO   NO    P1
# 4  NO   NO    P1

# %%
df_total.shape
# Out:
# (11299, 9)

# %%
df_total.dtypes
# Out:
# COLLEGE    object
# RANK       object
# LOC        object
# CAT        object
# SX         object
# MINOR      object
# NRI        object
# ACDS       object
# PHASE      object
# dtype: object

# %%
def determine_category(nri_value):
    if nri_value=='NRI':
        return 'C'
    else:
        return 'B'

# %%
df_total['Category'] = df_total['NRI'].apply(determine_category)
# Out:
# /var/folders/qk/cbjnsy590pn24y_t34wv1t500000gn/T/ipykernel_13623/2962247641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['Category'] = df_total['NRI'].apply(determine_category)

# %%
df_total.head(60)
# Out:
#                                               COLLEGE    RANK LOC  CAT SX  \
# 0   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   31229  OU   OC  M
# 1   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   32375  NL   OC  F
# 2   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   37371  NL  BCE  F
# 3   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   41646  NL   OC  F
# 4   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   41962  NL   OC  M
# 5   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   44584  NL   OC  M
# 6   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   45505  NL   OC  M
# 7   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   51606  NL   OC  M
# 8   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   63027  OU   OC  M
# 9   APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   65907  OU   OC  F
# 10  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   67523  OU   OC  M
# 11  APOLLO INSTITUTE OF MEDICAL SCIENCES AND RESEA...   79356  OU  BCD  M
# ...

# %%
df_total.to_csv('telanaganamanagement.csv',index=False)
